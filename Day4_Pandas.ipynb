# %%
import pandas as pd

print("Pandas imported successfully!")
# Out:
# Pandas imported successfully!

# %%
# Load Dataset
df = pd.read_csv("student_scores.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
print("----- First 5 Rows -----")
df.head()
# Out:
# ----- First 5 Rows -----
#               Name                    College   Course  Year  Math  Science  \
# 0    Gowthaami S M  KCG College of Technology  AI & DS     3    85       90
# 1       Jeevasri S  KCG College of Technology  AI & DS     3    78       82
# 2  Sathish kumar S  KCG College of Technology  AI & DS     3    92       89
# 3         Sifani J  KCG College of Technology  AI & DS     3    88       91
# 4       Pranathi P  KCG College of Technology  AI & DS     3    95       94
#
#    English
# 0       88
# 1       80
# 2       95
# 3       87
# 4       93

# %%
print("----- Last 5 Rows -----")
df.tail()
# Out:
# ----- Last 5 Rows -----
#               Name                    College   Course  Year  Math  Science  \
# 0    Gowthaami S M  KCG College of Technology  AI & DS     3    85       90
# 1       Jeevasri S  KCG College of Technology  AI & DS     3    78       82
# 2  Sathish kumar S  KCG College of Technology  AI & DS     3    92       89
# 3         Sifani J  KCG College of Technology  AI & DS     3    88       91
# 4       Pranathi P  KCG College of Technology  AI & DS     3    95       94
#
#    English
# 0       88
# 1       80
# 2       95
# 3       87
# 4       93

# %%
print("Rows and Columns:")
print(df.shape)
# Out:
# Rows and Columns:
# (5, 7)

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Name', 'College', 'Course', 'Year', 'Math', 'Science', 'English'], dtype='object')

# %%
print("Dataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   College  5 non-null      object
#  2   Course   5 non-null      object
#  3   Year     5 non-null      int64
#  4   Math     5 non-null      int64
#  5   Science  5 non-null      int64
#  6   English  5 non-null      int64
# dtypes: int64(4), object(3)
# memory usage: 412.0+ bytes

# %%
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#        Year       Math    Science   English
# count   5.0   5.000000   5.000000   5.00000
# mean    3.0  87.600000  89.200000  88.60000
# std     0.0   6.580274   4.438468   5.85662
# min     3.0  78.000000  82.000000  80.00000
# 25%     3.0  85.000000  89.000000  87.00000
# 50%     3.0  88.000000  90.000000  88.00000
# 75%     3.0  92.000000  91.000000  93.00000
# max     3.0  95.000000  94.000000  95.00000

# %%
print("NumPy and Pandas learning completed!")
print("Dataset loaded successfully.")
# Out:
# NumPy and Pandas learning completed!
# Dataset loaded successfully.
